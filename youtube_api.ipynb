# %%
# import libraries
import requests
import pandas as pd
import time 
#from googleapiclient.discovery import build

# %%
# keys
api_key = 'AIzaSyASeS22KBi2mR8qjf8PRJvGWkzwU9py5pQ'
channel_id = 'UCqlthGjbLIci7i3x2gk8P4Q'

# %% [markdown]
# api_service_name = "youtube"
# api_version = "v3"
# youtube = build(api_service_name, api_version, developerKey = api_key)

# %%
# make api call
pageToken = ""
url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+'&channelId='+channel_id+'&part=snippet,id&order=date&maxResults=10000'+pageToken
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'Os2ZL-_inS97MHTQP1735TnaBT8',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'CA',
#  'pageInfo': {'totalResults': 149, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '8ulGxTfg493eNQqfbK2LbogMk5Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'iejxvmCxpuY'},
#    'snippet': {'publishedAt': '2022-12-28T19:32:40Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Journey to Budva from Podgorica 🇲🇪',
#     'description': 'Journey to Budva from Podgorica #montenegro #budva #podgorica #balkans Follow me on Instagram for real-time travel ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iejxvmCxpuY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iejxvmCxpuY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iejxvmCxpuY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-28T19:32:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JfursRI1YoYhJ399wiAAFT-x2dY',
#    'id': {'kind': 'youtube#video', 'videoId': '_0oHMwk6IY8'},
#    'snippet': {'publishedAt': '2022-12-28T19:15:48Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Impressions of Podgorica, Montenegro 🇲🇪',
#     'description': 'First Impressions of Podgorica, Montenegro #montenegro #budva #podgorica #balkans Follow me on Instagram for real-time ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_0oHMwk6IY8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_0oHMwk6IY8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_0oHMwk6IY8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-28T19:15:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GndwQWFuc_rL3PhWxA7HXVPkWd8',
#    'id': {'kind': 'youtube#video', 'videoId': 'zpMvN-QM87M'},
#    'snippet': {'publishedAt': '2022-12-28T14:20:23Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Glacial Lake in Montenegro&#39;s mountains 🇲🇪',
#     'description': "Glacial Lake in Montenegro's mountains #montenegro #durmitor #crnojezero #blacklake Follow me on Instagram for ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zpMvN-QM87M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zpMvN-QM87M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zpMvN-QM87M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-28T14:20:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_iGx7jm39Gu2ELRzi0r9AaoLPKk',
#    'id': {'kind': 'youtube#video', 'videoId': 'tdReiQV2hNc'},
#    'snippet': {'publishedAt': '2022-12-28T09:00:27Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Amazing view from top of Montenegro 🇲🇪',
#     'description': 'Amazing view from top of Montenegro #montenegro #hiking #europe #durmitor.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tdReiQV2hNc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tdReiQV2hNc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tdReiQV2hNc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-28T09:00:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sqtrB0hGkfZy6qozm8fGNpBeTXs',
#    'id': {'kind': 'youtube#video', 'videoId': 'DqvMUfWlP3o'},
#    'snippet': {'publishedAt': '2022-12-28T06:00:02Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Treacherous Climb in Durmitor, Montenegro 🇲🇪',
#     'description': 'Treacherous Climb in Durmitor, Montenegro #montenegro #hiking #europe #durmitor.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DqvMUfWlP3o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DqvMUfWlP3o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DqvMUfWlP3o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-28T06:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'u0Tpmkf58Dq11jdyo8lEWByhM4s',
#    'id': {'kind': 'youtube#video', 'videoId': 'OgZOa-34Y3I'},
#    'snippet': {'publishedAt': '2022-12-27T18:41:33Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Furry Friends on Montenegro Hike 🇲🇪',
#     'description': 'Furry Friends on Montenegro Hike #montenegro #bobtovkuk #zabljak Follow me on Instagram for real-time travel updates: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OgZOa-34Y3I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OgZOa-34Y3I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OgZOa-34Y3I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-27T18:41:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AJq7g0ATKR9VNujyy1TD-prV0zA',
#    'id': {'kind': 'youtube#video', 'videoId': 'Bjd6ivDZi0Q'},
#    'snippet': {'publishedAt': '2022-12-27T18:18:47Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Up Montenegro&#39;s Highest Mountain  🇲🇪',
#     'description': "Up Montenegro's Highest Mountain #montenegro #hiking #europe.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bjd6ivDZi0Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Bjd6ivDZi0Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Bjd6ivDZi0Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-27T18:18:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'IQOJ4N9EM8Rv8aMwiFcOe-Q4fMI',
#    'id': {'kind': 'youtube#video', 'videoId': 'XsCYFsqONWQ'},
#    'snippet': {'publishedAt': '2022-12-26T19:06:58Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Journey To Bobotov Kuk ,Montenegro 🇲🇪',
#     'description': 'Journey To Bobotov Kuk ,Montenegro Full video: https://youtu.be/39wjZlnxuWM.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XsCYFsqONWQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XsCYFsqONWQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XsCYFsqONWQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-26T19:06:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KUmVoZxvMJ6inmOY0cuK_BNDbCg',
#    'id': {'kind': 'youtube#video', 'videoId': 'AiFlnAwxl0Q'},
#    'snippet': {'publishedAt': '2022-12-26T16:33:08Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Friendly Albanian knows Bollywood Classic 🇦🇱',
#     'description': 'Follow me on Instagram for real-time travel updates: https://www.instagram.com/nadironthego/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AiFlnAwxl0Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AiFlnAwxl0Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AiFlnAwxl0Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-26T16:33:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'EgOxxoRIBVC385jHKjE0wUZa9ck',
#    'id': {'kind': 'youtube#video', 'videoId': '28s1t0j9mrw'},
#    'snippet': {'publishedAt': '2022-12-25T18:59:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'DON&#39;T Do This To Dogs in Albania 🇦🇱',
#     'description': 'Follow me on Instagram for real-time travel updates: https://www.instagram.com/nadironthego/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/28s1t0j9mrw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/28s1t0j9mrw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/28s1t0j9mrw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-25T18:59:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'k0azzL9CaVNUpOBKajYAs996Tgc',
#    'id': {'kind': 'youtube#video', 'videoId': 'kxSHlcRc_Jw'},
#    'snippet': {'publishedAt': '2022-12-25T13:38:46Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': '$0.90 Street Hot Dog in Durres, Albania 🇦🇱',
#     'description': 'Follow me on Instagram for real-time travel updates: https://www.instagram.com/nadironthego/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kxSHlcRc_Jw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kxSHlcRc_Jw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kxSHlcRc_Jw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-25T13:38:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vee7R_nokt4c8wlNXO2ZCORESgU',
#    'id': {'kind': 'youtube#video', 'videoId': '7T_Z801GNc0'},
#    'snippet': {'publishedAt': '2022-12-24T06:00:02Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': '$3.50 Shave in Tirana, Albania 🇦🇱',
#     'description': 'Follow me on Instagram for real-time travel updates: https://www.instagram.com/nadironthego/ Music used is from Epidemic ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7T_Z801GNc0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7T_Z801GNc0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7T_Z801GNc0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-24T06:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VnwbJn3Ts6_D0UlquA3ihPz3CZ8',
#    'id': {'kind': 'youtube#video', 'videoId': 'EZ2G369Gi7k'},
#    'snippet': {'publishedAt': '2022-12-22T15:42:21Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Ottoman Relics in Skopje, Macedonia 🇲🇰',
#     'description': 'Full video: https://youtu.be/Zw_v1po-t5s Follow me on Instagram for real-time travel updates: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EZ2G369Gi7k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EZ2G369Gi7k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EZ2G369Gi7k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-22T15:42:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TL09n9kYMplCCTUhFfEOwxwuXhY',
#    'id': {'kind': 'youtube#video', 'videoId': 'KnO4jpAHHuM'},
#    'snippet': {'publishedAt': '2022-12-21T16:35:47Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Cliff-diving in Montenegro 🇲🇪',
#     'description': 'Full video: https://youtu.be/vOlxiLh8Xzg Follow me on Instagram for real-time travel updates: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KnO4jpAHHuM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KnO4jpAHHuM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KnO4jpAHHuM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-21T16:35:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nNeYgeACr3DBqECAycNkN_J5FQk',
#    'id': {'kind': 'youtube#video', 'videoId': 'Na2AiW3hvAQ'},
#    'snippet': {'publishedAt': '2022-12-21T06:00:09Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'A Nuclear Bunker Bigger Than a Palace 🇦🇱',
#     'description': 'Full video: https://youtu.be/ikdjrnVPPNY In the full video video, I do a deep dive into Communism in Albania and the 4 decades ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Na2AiW3hvAQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Na2AiW3hvAQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Na2AiW3hvAQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-21T06:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'B31onWzv2JQB9Xarc7Eiw-SOzPo',
#    'id': {'kind': 'youtube#video', 'videoId': 'nj7yoopmUy4'},
#    'snippet': {'publishedAt': '2022-12-20T11:35:57Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Bus from Tirana, Albania to Skopje, Macedonia 🇦🇱 🇲🇰',
#     'description': 'Journey from Albania to Macedonia through Ohrid Full video: https://youtu.be/Zw_v1po-t5s Follow me on Instagram for real-time ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nj7yoopmUy4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nj7yoopmUy4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nj7yoopmUy4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-20T11:35:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'roXw3_Dg41rdvGwvJQyciFqP5x8',
#    'id': {'kind': 'youtube#video', 'videoId': 'Zw_v1po-t5s'},
#    'snippet': {'publishedAt': '2022-12-17T06:30:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Day in North Macedonia - Skopje Vlog 🇲🇰',
#     'description': "In this video we step into the land of Alexander the Great's Macedon and the modern country of North Macedonia which has ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zw_v1po-t5s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Zw_v1po-t5s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Zw_v1po-t5s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-17T06:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KwVLndGsXjOXRkAqTlZu7FCwZ38',
#    'id': {'kind': 'youtube#video', 'videoId': 'PeW7vRTC2tE'},
#    'snippet': {'publishedAt': '2022-11-29T14:00:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Tirana New Bazaar - Albania Market Hunt Vlog 🇦🇱',
#     'description': "An afternoon stroll to check out what's for sale in the Pazari i Ri or New Bazaar of Tirana, Albania Follow me on Instagram for ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PeW7vRTC2tE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PeW7vRTC2tE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PeW7vRTC2tE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-29T14:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'crSjkn9Bi9YOYpKuVD6W1iGasas',
#    'id': {'kind': 'youtube#video', 'videoId': 'ikdjrnVPPNY'},
#    'snippet': {'publishedAt': '2022-11-22T07:30:09Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'No One Entered Or Left This Country for 40 Years!',
#     'description': 'Sign up HERE https://bit.ly/3DKlbPG for your discounted offer to Epidemic Sound! ← The offer will be available for 5 days only.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-22T07:30:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lZUzmGHlV1XPzXB9hP6ulKMh3SY',
#    'id': {'kind': 'youtube#video', 'videoId': 'HyiqzvOWf3k'},
#    'snippet': {'publishedAt': '2022-11-11T18:30:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 
00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hmkkLWS_lTWuzd2V0cX0ExqoeV0',
#    'id': {'kind': 'youtube#video', 'videoId': '39wjZlnxuWM'},
#    'snippet': {'publishedAt': '2022-09-22T16:15:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Dangerous Climb Up Bobotov Kuk - Durmitor, Montenegro 🇲🇪',
#     'description': 'I traveled to Žabljak in Durmitor National Park and climbed up the highest mountain in Montenegro, Bobotov Kuk, at 2500 m.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/39wjZlnxuWM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/39wjZlnxuWM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/39wjZlnxuWM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-22T16:15:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'T0gpTtnnli_gBNmpHRqpN56oBes',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLMQNNpGZnyg4jpuXx5eEK7irZ-grCQmFa'},
#    'snippet': {'publishedAt': '2022-09-22T12:56:57Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Montenegro - Nadir On The Go - English',
#     'description': 'All videos from Montenegro.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wXspMUN1CdI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wXspMUN1CdI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wXspMUN1CdI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-22T12:56:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OKSWLwUfrkTwW_6zvidtq5Q0w1k',
#    'id': {'kind': 'youtube#video', 'videoId': 'vOlxiLh8Xzg'},
#    'snippet': {'publishedAt': '2022-09-13T13:00:09Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Impressions of Budva, Montenegro 🇲🇪',
#     'description': "I traveled to Montenegro's premiere tourist destination, the coastal city of Budva, and explored the expensive resort town on a ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vOlxiLh8Xzg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vOlxiLh8Xzg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vOlxiLh8Xzg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-13T13:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TYChvVu8iJS-cS85J9PAAGSI8LY',
#    'id': {'kind': 'youtube#video', 'videoId': 'GDg3l0QPEBM'},
#    'snippet': {'publishedAt': '2022-08-18T13:00:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'The Future of Travel - eSim Holafly Review',
#     'description': 'Here I discuss how e-sims are making travel wayy easier for all of us who have struggled with figuring out how a new country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GDg3l0QPEBM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GDg3l0QPEBM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GDg3l0QPEBM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-18T13:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9_9q8qW4ot84nBhS3IqAmPvEzCQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'lBS04wo6E3k'},
#    'snippet': {'publishedAt': '2022-08-17T13:30:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Kafanas Are Lit - Traditional Tavern in Serbia 🇷🇸',
#     'description': 'I went to a traditional kafana at the heart of Belgrade, which is a traditional Balkan tavern with its own unique vibe. Was blown ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lBS04wo6E3k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lBS04wo6E3k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lBS04wo6E3k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-17T13:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3BsXu4FjNQZhjQprF71U8awNxFQ',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLMQNNpGZnyg49nd6Rnh5Y-6b8GCvkbAo9'},
#    'snippet': {'publishedAt': '2022-08-17T08:51:04Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Balkans - Nadir On The Go - English',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-17T08:51:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TMVEz6nZTv_0SPvgNsSljlTVHSA',
#    'id': {'kind': 'youtube#video', 'videoId': 'TlNz8nq1i-o'},
#    'snippet': {'publishedAt': '2022-08-10T13:00:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'In Nepal&#39;s Dangerous Jungle - Chitwan National Park 🇳🇵',
#     'description': 'In this video, we go into Chitwan, riddled with tigers terrorizing the locals, the most Asian rhinos anywhere, wild elephants, bears ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TlNz8nq1i-o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TlNz8nq1i-o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TlNz8nq1i-o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-10T13:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ch_wfiCGrXNfqOgYBnANefihnGk',
#    'id': {'kind': 'youtube#video', 'videoId': 'oFcz_Vwba_I'},
#    'snippet': {'publishedAt': '2022-08-09T06:00:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Fascinating Funeral Rituals in Kathmandu, Nepal 🇳🇵',
#     'description': 'We visit 2 of the holiest temples in Nepal, the Buddhist Boudhanath temple and the legendary Pashupatinath temple, both ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oFcz_Vwba_I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oFcz_Vwba_I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oFcz_Vwba_I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-09T06:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mMJJ7jYB1RBkvLW4wz3REhZrElk',
#    'id': {'kind': 'youtube#video', 'videoId': 'N0KNrk2YCnU'},
#    'snippet': {'publishedAt': '2022-08-02T13:00:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Journey Into the Himalayas 🇳🇵 - The Annapurna Finale',
#     'description': 'In the second part of the journey, I complete the 4 day trek into the Annapurna sanctuary in the Himalayas, one of the most ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/N0KNrk2YCnU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/N0KNrk2YCnU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/N0KNrk2YCnU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-02T13:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MXvUy_dTLlRKzJXOSuY9j0Fq7fM',
#    'id': {'kind': 'youtube#video', 'videoId': 'r8n_OqrK-Og'},
#    'snippet': {'publishedAt': '2022-07-29T13:00:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Journey Into the Himalayas 🇳🇵 - Part 1 of 2',
#     'description': 'I took a 4 day trek into the Himalayas of Nepal and up to the biggest mountains in the world as I set on the Mardi Himal trek in the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/r8n_OqrK-Og/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/r8n_OqrK-Og/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/r8n_OqrK-Og/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-29T13:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wnkktyxyodhQS8YD2MDxvNK5ok4',
#    'id': {'kind': 'youtube#video', 'videoId': 'Jw1i5ClXi60'},
#    'snippet': {'publishedAt': '2022-07-21T13:00:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Visiting Nepal&#39;s Ancient Capital City - Bhaktapur Vlog 🇳🇵',
#     'description': 'In the second video from Nepal, I explored Bhaktapur, the former capital of the Malla Kingdom that ruled the entire Kathmandu, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Jw1i5ClXi60/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Jw1i5ClXi60/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Jw1i5ClXi60/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-21T13:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'S_VrdqZI3v2a06hH46oGlSxdo0w',
#    'id': {'kind': 'youtube#video', 'videoId': 'I6tBr9d-UmI'},
#    'snippet': {'publishedAt': '2022-07-13T06:00:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Visiting Prophet Adam&#39;s First Footstep - Adam&#39;s Peak 🇱🇰',
#     'description': "In the last video from Sri Lanka, we climbed the sacred mountain called Adam's Peak (Sri Pada in Sri Lankan) to see a rock ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/I6tBr9d-UmI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/I6tBr9d-UmI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/I6tBr9d-UmI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-13T06:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'J8JWw6gS81c8r09pwnNTzYgtg9s',
#    'id': {'kind': 'youtube#video', 'videoId': '89pCHrEtD6Y'},
#    'snippet': {'publishedAt': '2022-07-11T13:45:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'World-Famous Ella Train Ride - Sri Lanka 🇱🇰',
#     'description': 'We took the world famous gorgeous train journey from Ella to Kandy (technically 2/3 of it but the most scenic part) and started our ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/89pCHrEtD6Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/89pCHrEtD6Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/89pCHrEtD6Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-11T13:45:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bj8bGzry_quY0UW0hbZLSatXo2s',
#    'id': {'kind': 'youtube#video', 'videoId': 'ksE5SflUgiU'},
#    'snippet': {'publishedAt': '2022-07-08T11:49:50Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Face to Face with Wild Elephant Family - Udawalawe, Sri Lanka 🇱🇰',
#     'description': 'On the road from the south beaches to the mountains of Ella, I stopped by Udawalawe National Park. They say you have to be ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ksE5SflUgiU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ksE5SflUgiU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ksE5SflUgiU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-08T11:49:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XRshVEJ851E_qQuPTDeP6JNgpog',
#    'id': {'kind': 'youtube#video', 'videoId': 'awKWqzSPLa8'},
#    'snippet': {'publishedAt': '2022-07-03T05:00:08Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': '
12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Impressions of Jaisalmer - Rajasthan Vlog 🇮🇳',
#     'description': "In this jam-packed Rajasthan vlog, I visited India's golden city of Jaisalmer. First I went to India's only living fort, the Jaisalmer fort, ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oHpLkdwBGEU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oHpLkdwBGEU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oHpLkdwBGEU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-20T15:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TNbOvijxlpWtSFJL0ePz3_hMagE',
#    'id': {'kind': 'youtube#video', 'videoId': 'i6Fy1l98mVQ'},
#    'snippet': {'publishedAt': '2022-04-04T13:30:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Jodhpur is Intense - Rajasthan Day 1 🇮🇳',
#     'description': "Jodhpur, India's blue city, had been high on my bucket list since I watched it in one of my favorite Hollywood movies 10 years ago ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i6Fy1l98mVQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i6Fy1l98mVQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i6Fy1l98mVQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-04T13:30:11Z'}}]}

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '8ulGxTfg493eNQqfbK2LbogMk5Q',
#  'id': {'kind': 'youtube#video', 'videoId': 'iejxvmCxpuY'},
#  'snippet': {'publishedAt': '2022-12-28T19:32:40Z',
#   'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#   'title': 'Journey to Budva from Podgorica 🇲🇪',
#   'description': 'Journey to Budva from Podgorica #montenegro #budva #podgorica #balkans Follow me on Instagram for real-time travel ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iejxvmCxpuY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/iejxvmCxpuY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/iejxvmCxpuY/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Nadir On The Go',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2022-12-28T19:32:40Z'}}

# %%
video_id = response['items'][0]['id']['videoId']
video_title = response['items'][0]['snippet']['title']
video_title = video_title.replace("&amp;", "")
upload_date = response['items'][0]['snippet']['publishTime']
upload_date = upload_date.split("T")[0]

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = video_title.replace("&amp;", "")
        upload_date = video['snippet']['publishTime']
        upload_date = upload_date.split("T")[0]
        
        print(video_id)
        print(video_title)
        print(upload_date)
# Out:
# iejxvmCxpuY
# Journey to Budva from Podgorica 🇲🇪
# 2022-12-28
# _0oHMwk6IY8
# First Impressions of Podgorica, Montenegro 🇲🇪
# 2022-12-28
# zpMvN-QM87M
# Glacial Lake in Montenegro&#39;s mountains 🇲🇪
# 2022-12-28
# tdReiQV2hNc
# Amazing view from top of Montenegro 🇲🇪
# 2022-12-28
# DqvMUfWlP3o
# Treacherous Climb in Durmitor, Montenegro 🇲🇪
# 2022-12-28
# OgZOa-34Y3I
# Furry Friends on Montenegro Hike 🇲🇪
# 2022-12-27
# Bjd6ivDZi0Q
# Up Montenegro&#39;s Highest Mountain  🇲🇪
# 2022-12-27
# XsCYFsqONWQ
# Journey To Bobotov Kuk ,Montenegro 🇲🇪
# 2022-12-26
# AiFlnAwxl0Q
# Friendly Albanian knows Bollywood Classic 🇦🇱
# 2022-12-26
# 28s1t0j9mrw
# DON&#39;T Do This To Dogs in Albania 🇦🇱
# 2022-12-25
# kxSHlcRc_Jw
# $0.90 Street Hot Dog in Durres, Albania 🇦🇱
# 2022-12-25
# 7T_Z801GNc0
# $3.50 Shave in Tirana, Albania 🇦🇱
# 2022-12-24
# EZ2G369Gi7k
# Ottoman Relics in Skopje, Macedonia 🇲🇰
# 2022-12-22
# KnO4jpAHHuM
# Cliff-diving in Montenegro 🇲🇪
# 2022-12-21
# 2022-05-20
# uk6PY3v3038
# Is it Safe to Travel Sri Lanka Now? 🇱🇰 - Shocking Reality of Tourist Life in the Crisis
# 2022-05-09
# oHpLkdwBGEU
# First Impressions of Jaisalmer - Rajasthan Vlog 🇮🇳
# 2022-04-20
# i6Fy1l98mVQ
# Jodhpur is Intense - Rajasthan Day 1 🇮🇳
# 2022-04-04

# %%
url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
response_video_stats = requests.get(url_video_stats).json()

# %%
response_video_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'kG8mHTuyRZjfpqbpEfn6I_-4omc',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'jMygnlzjfVDy0Jq8nvhoUK0v2zc',
#    'id': 'i6Fy1l98mVQ',
#    'statistics': {'viewCount': '29327',
#     'likeCount': '1713',
#     'favoriteCount': '0',
#     'commentCount': '131'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
if 'viewCount' in response_video_stats['items'][0]['statistics']:
    view_count = response_video_stats['items'][0]['statistics']['viewCount']
else:
    view_count = None
if 'likeCount' in response_video_stats['items'][0]['statistics']:
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
else:
    like_count = None
if 'dislikeCount' in response_video_stats['items'][0]['statistics']:
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
else:
    dislike_count = None
if 'commentCount' in response_video_stats['items'][0]['statistics']:
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']
else:
    comment_count = None

# %%
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count", "dislike_count", "comment_count"])

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = video_title.replace("&amp;", "")
        upload_date = video['snippet']['publishTime']
        upload_date = upload_date.split("T")[0]
        
        url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
        response_video_stats = requests.get(url_video_stats).json()
        if 'viewCount' in response_video_stats['items'][0]['statistics']:
            view_count = response_video_stats['items'][0]['statistics']['viewCount']
        else:
            view_count = None
        if 'likeCount' in response_video_stats['items'][0]['statistics']:
            like_count = response_video_stats['items'][0]['statistics']['likeCount']
        else:
            like_count = None
        if 'dislikeCount' in response_video_stats['items'][0]['statistics']:
            dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
        else:
            dislike_count = None
        if 'commentCount' in response_video_stats['items'][0]['statistics']:
            comment_count = response_video_stats['items'][0]['statistics']['commentCount']
        else:
            comment_count = None
        """
        print(video_id)
        print(video_title)
        print(upload_date)
        print(view_count)
        print(like_count)
        print(dislike_count)
        print(comment_count)
        """
        #save data in pandas dataframe
        df = df.append({'video_id':video_id, 'video_title':video_title,
                        'upload_date':upload_date, 'view_count':view_count,
                        'like_count':like_count, 'dislike_count':dislike_count,
                        'comment_count':comment_count}, ignore_index=True)

# %%
df.head()
# Out:
#       video_id                                    video_title upload_date  \
# 0  iejxvmCxpuY             Journey to Budva from Podgorica 🇲🇪  2022-12-28
# 1  _0oHMwk6IY8  First Impressions of Podgorica, Montenegro 🇲🇪  2022-12-28
# 2  zpMvN-QM87M  Glacial Lake in Montenegro&#39;s mountains 🇲🇪  2022-12-28
# 3  tdReiQV2hNc         Amazing view from top of Montenegro 🇲🇪  2022-12-28
# 4  DqvMUfWlP3o   Treacherous Climb in Durmitor, Montenegro 🇲🇪  2022-12-28
#
#   view_count like_count dislike_count comment_count
# 0        228         19          None             0
# 1       1062         56          None             4
# 2        464         55          None             2
# 3        386         52          None             4
# 4        550         50          None             1

# %%
def call_api(api_key, channel_id):
    pageToken = ""
    url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+'&channelId='+channel_id+'&part=snippet,id&order=date&maxResults=10000'+pageToken
    response = requests.get(url).json()
    return response

# %%
def get_video_details(video_id):
    url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
    response_video_stats = requests.get(url_video_stats).json()
    if 'viewCount' in response_video_stats['items'][0]['statistics']:
        view_count = response_video_stats['items'][0]['statistics']['viewCount']
    else:
        view_count = None
    if 'likeCount' in response_video_stats['items'][0]['statistics']:
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
    else:
        like_count = None
    if 'dislikeCount' in response_video_stats['items'][0]['statistics']:
        dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
    else:
        dislike_count = None
    if 'commentCount' in response_video_stats['items'][0]['statistics']:
        comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    else:
        comment_count = None
    
    return view_count, like_count, dislike_count, comment_count

# %%
def get_videos(response, df):
    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            video_title = video_title.replace("&amp;", "")
            upload_date = video['snippet']['publishTime']
            upload_date = upload_date.split("T")[0]
            
            view_count, like_count, dislike_count, comment_count = get_video_details(video_id)

            #save data in pandas dataframe
            df = df.append({'video_id':video_id, 'video_title':video_title,
                            'upload_date':upload_date, 'view_count':view_count,
                            'like_count':like_count, 'dislike_count':dislike_count,
                            'comment_count':comment_count}, ignore_index=True)
    return df

# %%
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count", "dislike_count", "comment_count"])

# %%
# keys
api_key = 'AIzaSyASeS22KBi2mR8qjf8PRJvGWkzwU9py5pQ'
channel_id = 'UCyV7cn5xPsPexvdY8Lig3-g'
response = call_api(api_key, channel_id)
df = get_videos(response, df)

# %%
df['dislike_count'] = 0
df.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  kLkmGUTwG-s  Comment | Java for Beginners | Bangla Tutorial...  2021-01-05
# 1  baGEPw5XMog  How To Run A Java Program | Java for Beginners...  2020-10-18
# 2  47y_BeKHIPs  C++ vs Java | Java for Beginners | Bangla Tuto...  2020-09-28
# 3  sKUZAeyF_QU  Overview of Java | Java for Beginners | Bangla...  2020-09-03
# 4  hl4eq1ToX3U  How To Add A Calendar To A Website | Bangla We...  2020-08-31
#
#   view_count like_count  dislike_count comment_count
# 0         67          4              0             0
# 1        155          6              0             1
# 2        123          2              0             1
# 3        100          7              0             2
# 4         70         10              0             4

# %%
df.to_csv('data.csv')
