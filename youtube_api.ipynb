# %%
# import libraries
import requests
import pandas as pd
import time 
#from googleapiclient.discovery import build

# %%
# keys
api_key = 'AIzaSyASeS22KBi2mR8qjf8PRJvGWkzwU9py5pQ'
channel_id = 'UCqlthGjbLIci7i3x2gk8P4Q'

# %% [markdown]
# api_service_name = "youtube"
# api_version = "v3"
# youtube = build(api_service_name, api_version, developerKey = api_key)

# %%
# make api call
pageToken = ""
url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+'&channelId='+channel_id+'&part=snippet,id&order=date&maxResults=10000'+pageToken
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'peDFXiwZSdYfkUNqgAQfvsb_5vo',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 127, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'ro_V3yTYa6uaNj99u4y9qbiqL-k',
#    'id': {'kind': 'youtube#video', 'videoId': 'ikdjrnVPPNY'},
#    'snippet': {'publishedAt': '2022-11-22T07:30:09Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'No One Could Enter OR Leave This Country for 40 years..',
#     'description': 'Sign up HERE https://bit.ly/3DKlbPG for your discounted offer to Epidemic Sound! ← The offer will be available for 5 days only.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-22T07:30:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lZUzmGHlV1XPzXB9hP6ulKMh3SY',
#    'id': {'kind': 'youtube#video', 'videoId': 'HyiqzvOWf3k'},
#    'snippet': {'publishedAt': '2022-11-11T18:30:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'How did I end up on Albanian News?🇦🇱',
#     'description': 'How does a Travel Vlogger make it to Euronews Albania? Good question. This is how. Full video link on Euronews Albania: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HyiqzvOWf3k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HyiqzvOWf3k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HyiqzvOWf3k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-11T18:30:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RCvXdeflEpT6BUWWMcsQZFTbgOc',
#    'id': {'kind': 'youtube#video', 'videoId': 'NCR2elB4NWs'},
#    'snippet': {'publishedAt': '2022-11-03T18:34:05Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Dangerous Hike in Albanian Alps 🇦🇱',
#     'description': 'shorts The peak near Theth to Valbona hike in the Albanian Alps of Northeastern Albania near the Montenegro border. Full video: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NCR2elB4NWs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NCR2elB4NWs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NCR2elB4NWs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-03T18:34:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sNck2c4WOWp-PKP6XrLvi0LgHKs',
#    'id': {'kind': 'youtube#video', 'videoId': 'gsN_g3UfYLc'},
#    'snippet': {'publishedAt': '2022-10-30T17:00:09Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'The Albanian Alps -  Theth to Valbona hike 🇦🇱',
#     'description': 'We went to the Albanian alps to do the gorgeous hike from Theth to Valbona, and documented our journey as we left from ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gsN_g3UfYLc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gsN_g3UfYLc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gsN_g3UfYLc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-30T17:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7D1uMaUcJXgkrq7xBDmjEyzFvn4',
#    'id': {'kind': 'youtube#video', 'videoId': 'cEYcsrN6c-g'},
#    'snippet': {'publishedAt': '2022-10-22T14:00:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Day in Tirana - Albania Vlog 🇦🇱',
#     'description': 'I traveled from UIcinj, Montenegro, to Tirana, Albania, with a stop at Shkoder, and in this video I captured the experience of the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cEYcsrN6c-g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cEYcsrN6c-g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cEYcsrN6c-g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-22T14:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GKQDm-fjaHhTdKP4_navC7UQ-AU',
#    'id': {'kind': 'youtube#video', 'videoId': 'CyxzEGHcLNc'},
#    'snippet': {'publishedAt': '2022-10-19T10:52:27Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Prokletije Sunset in Montenegro 🇲🇪',
#     'description': 'Clip for the larger Prokletije National Park video of hiking from Montenegro to Albania. Full video: https://youtu.be/kzi5qq7LlVw.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CyxzEGHcLNc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CyxzEGHcLNc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CyxzEGHcLNc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-19T10:52:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Dhn_8MXoLNRVtFlioCzkMTaH4U4',
#    'id': {'kind': 'youtube#video', 'videoId': 'kzi5qq7LlVw'},
#    'snippet': {'publishedAt': '2022-10-06T13:00:13Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'I Hiked from Montenegro to Albania - Peaks of the Balkans 🇲🇪',
#     'description': 'In this Grebaje Valley hike in Prokletije National Park (Accursed Mountains), I conquered Taljanka on a hike that goes from ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kzi5qq7LlVw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kzi5qq7LlVw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kzi5qq7LlVw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-06T13:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hmkkLWS_lTWuzd2V0cX0ExqoeV0',
#    'id': {'kind': 'youtube#video', 'videoId': '39wjZlnxuWM'},
#    'snippet': {'publishedAt': '2022-09-22T16:15:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Dangerous Climb Up Bobotov Kuk - Durmitor, Montenegro 🇲🇪',
#     'description': 'I traveled to Žabljak in Durmitor National Park and climbed up the highest mountain in Montenegro, Bobotov Kuk, at 2500 m.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/39wjZlnxuWM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/39wjZlnxuWM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/39wjZlnxuWM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-22T16:15:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OKSWLwUfrkTwW_6zvidtq5Q0w1k',
#    'id': {'kind': 'youtube#video', 'videoId': 'vOlxiLh8Xzg'},
#    'snippet': {'publishedAt': '2022-09-13T13:00:09Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Impressions of Budva, Montenegro 🇲🇪',
#     'description': "I traveled to Montenegro's premiere tourist destination, the coastal city of Budva, and explored the expensive resort town on a ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vOlxiLh8Xzg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vOlxiLh8Xzg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vOlxiLh8Xzg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-13T13:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TYChvVu8iJS-cS85J9PAAGSI8LY',
#    'id': {'kind': 'youtube#video', 'videoId': 'GDg3l0QPEBM'},
#    'snippet': {'publishedAt': '2022-08-18T13:00:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'The Future of Travel - eSim Holafly Review',
#     'description': 'Here I discuss how e-sims are making travel wayy easier for all of us who have struggled with figuring out how a new country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GDg3l0QPEBM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GDg3l0QPEBM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GDg3l0QPEBM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-18T13:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9_9q8qW4ot84nBhS3IqAmPvEzCQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'lBS04wo6E3k'},
#    'snippet': {'publishedAt': '2022-08-17T13:30:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Kafanas Are Lit - Traditional Tavern in Serbia 🇷🇸',
#     'description': 'I went to a traditional kafana at the heart of Belgrade, which is a traditional Balkan tavern with its own unique vibe. Was blown ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lBS04wo6E3k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lBS04wo6E3k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lBS04wo6E3k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-17T13:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0kXdJsXY2TWbf_JJlAU3MIg3JjU',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLMQNNpGZnyg49nd6Rnh5Y-6b8GCvkbAo9'},
#    'snippet': {'publishedAt': '2022-08-17T08:51:04Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Balkans - Nadir On The Go - English',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-17T08:51:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TMVEz6nZTv_0SPvgNsSljlTVHSA',
#    'id': {'kind': 'youtube#video', 'videoId': 'TlNz8nq1i-o'},
#    'snippet': {'publishedAt': '2022-08-10T13:00:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'In Nepal&#39;s Dangerous Jungle - Chitwan National Park 🇳🇵',
#     'description': 'In this video, we go into Chitwan, riddled with tigers terrorizing the locals, the most Asian rhinos anywhere, wild elephants, bears ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TlNz8nq1i-o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TlNz8nq1i-o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TlNz8nq1i-o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-10T13:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ch_wfiCGrXNfqOgYBnANefihnGk',
#    'id': {'kind': 'youtube#video', 'videoId': 'oFcz_Vwba_I'},
#    'snippet': {'publishedAt': '2022-08-09T06:00:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Fascinating Funeral Rituals in Kathmandu, Nepal 🇳🇵',
#     'description': 'We visit 2 of the holiest temples in Nepal, the Buddhist Boudhanath temple and the legendary Pashupatinath temple, both ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oFcz_Vwba_I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oFcz_Vwba_I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oFcz_Vwba_I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-09T06:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mMJJ7jYB1RBkvLW4wz3REhZrElk',
#    'id': {'kind': 'youtube#video', 'videoId': 'N0KNrk2YCnU'},
#    'snippet': {'publishedAt': '2022-08-02T13:00:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Journey Into the Himalayas 🇳🇵 - The Annapurna Finale',
#     'description': 'In the second part of the journey, I complete the 4 day trek into the Annapurna sanctuary in the Himalayas, one of the most ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/N0KNrk2YCnU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/N0KNrk2YCnU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/N0KNrk2YCnU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-02T13:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MXvUy_dTLlRKzJXOSuY9j0Fq7fM',
#    'id': {'kind': 'youtube#video', 'videoId': 'r8n_OqrK-Og'},
#    'snippet': {'publishedAt': '2022-07-29T13:00:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Journey Into the Himalayas 🇳🇵 - Part 1 of 2',
#     'description': 'I took a 4 day trek into the Himalayas of Nepal and up to the biggest mountains in the world as I set on the Mardi Himal trek in the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/r8n_OqrK-Og/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/r8n_OqrK-Og/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/r8n_OqrK-Og/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-29T13:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wnkktyxyodhQS8YD2MDxvNK5ok4',
#    'id': {'kind': 'youtube#video', 'videoId': 'Jw1i5ClXi60'},
#    'snippet': {'publishedAt': '2022-07-21T13:00:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Visiting Nepal&#39;s Ancient Capital City - Bhaktapur Vlog 🇳🇵',
#     'description': 'In the second video from Nepal, I explored Bhaktapur, the former capital of the Malla Kingdom that ruled the entire Kathmandu, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Jw1i5ClXi60/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Jw1i5ClXi60/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Jw1i5ClXi60/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-21T13:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'S_VrdqZI3v2a06hH46oGlSxdo0w',
#    'id': {'kind': 'youtube#video', 'videoId': 'I6tBr9d-UmI'},
#    'snippet': {'publishedAt': '2022-07-13T06:00:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Visiting Prophet Adam&#39;s First Footstep - Adam&#39;s Peak 🇱🇰',
#     'description': "In the last video from Sri Lanka, we climbed the sacred mountain called Adam's Peak (Sri Pada in Sri Lankan) to see a rock ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/I6tBr9d-UmI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/I6tBr9d-UmI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/I6tBr9d-UmI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-13T06:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'J8JWw6gS81c8r09pwnNTzYgtg9s',
#    'id': {'kind': 'youtube#video', 'videoId': '89pCHrEtD6Y'},
#    'snippet': {'publishedAt': '2022-07-11T13:45:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'World-Famous Ella Train Ride - Sri Lanka 🇱🇰',
#     'description': 'We took the world famous gorgeous train journey from Ella to Kandy (technically 2/3 of it but the most scenic part) and started our ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/89pCHrEtD6Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/89pCHrEtD6Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/89pCHrEtD6Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-11T13:45:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bj8bGzry_quY0UW0hbZLSatXo2s',
#    'id': {'kind': 'youtube#video', 'videoId': 'ksE5SflUgiU'},
#    'snippet': {'publishedAt': '2022-07-08T11:49:50Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Face to Face with Wild Elephant Family - Udawalawe, Sri Lanka 🇱🇰',
#     'description': 'On the road from the south beaches to the mountains of Ella, I stopped by Udawalawe National Park. They say you have to be ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ksE5SflUgiU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ksE5SflUgiU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ksE5SflUgiU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-08T11:49:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XRshVEJ851E_qQuPTDeP6JNgpog',
#    'id': {'kind': 'youtube#video', 'videoId': 'awKWqzSPLa8'},
#    'snippet': {'publishedAt': '2022-07-03T05:00:08Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Venomous Snakes &amp; The Wildest Beaches - Sri Lanka  🇱🇰',
#     'description': 'After 10 amazing weeks on the coast of South Sri Lanka, I tried to sum of the best spots and activities in this short vlog from Mirissa ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/awKWqzSPLa8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/awKWqzSPLa8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/awKWqzSPLa8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-03T05:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DrAQA0Y2ohO5EZxfjmO1BA78iJE',
#    'id': {'kind': 'youtube#video', 'videoId': 'zvy3ZaVIfPY'},
#    'snippet': {'publishedAt': '2022-06-29T04:30:09Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Impressions of Nepal - Kathmandu Day 1 🇳🇵',
#     'description': 'Documenting my first day in Kathmandu, Nepal with visits to bustling South Asian markets of the capital city, exploring the unique ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zvy3ZaVIfPY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zvy3ZaVIfPY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zvy3ZaVIfPY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-29T04:30:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'igPIP1CWjrvKaMkaisiDVydIToY',
#    'id': {'kind': 'youtube#video', 'videoId': '5zDr5HhBQi0'},
#    'snippet': {'publishedAt': '2022-06-26T14:00:14Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Agra Vlog - The Mughal Empire&#39;s Story  🇮🇳',
#     'description': 'In this Agra vlog, we explore the most historic sites and mausoleums in the former capital of the Mughal Empire. We also learn the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5zDr5HhBQi0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5zDr5HhBQi0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5zDr5HhBQi0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-26T14:00:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'L-_S-V0lTtqHC2nKkKr4agI8Fkg',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLMQNNpGZnyg6mNlOh8rSmI7jXozeDwJlk'},
#    'snippet': {'publishedAt': '2022-06-19T15:06:57Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Nepal - Nadir On The Go - English',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zvy3ZaVIfPY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zvy3ZaVIfPY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zvy3ZaVIfPY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-19T15:06:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hbVHKt14dN40vbDzxjyX7ZhKss0',
#    'id': {'kind': 'youtube#video', 'videoId': 'dfH5c429gIk'},
#    'snippet': {'publishedAt': '2022-06-09T16:38:26Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Attacked by Wild Monkey in Jaipur | Pink City Vlog 🇮🇳',
#     'description': 'The highlight of this video inadvertently became the lemur monkey attack, but this is a bigger historical travel vlog from Jaipur, the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dfH5c429gIk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dfH5c429gIk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dfH5c429gIk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-09T16:38:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aqmO57aavLXtBPbyeqZVueKjbdk',
#    'id': {'kind': 'youtube#video', 'videoId': 'f2uo7rYE3-g'},
#    'snippet': {'publishedAt': '2022-05-20T14:29:54Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Himalayas Sunrise - Annapurna Sanctuary 🇳🇵',
#     'description': 'shorts Sunrise at the Annapurna Sanctuary in the Himalayan mountains Full video from the trek: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f2uo7rYE3-g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f2uo7rYE3-g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f2uo7rYE3-g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-20T14:29:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kZ9yMe6tBnUdgdKmoIT3hoHdncA',
#    'id': {'kind': 'youtube#video', 'videoId': 'uk6PY3v3038'},
#    'snippet': {'publishedAt': '2022-05-09T13:00:02Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Is it Safe to Travel Sri Lanka Now? 🇱🇰 - Shocking Reality of Tourist Life in the Crisis',
#     'description': 'I was in Sri Lanka for the last 3 months (Feb- May 2022) as a tourist amidst the economy collapsing and saw the Sri Lankan ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uk6PY3v3038/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uk6PY3v3038/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uk6PY3v3038/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-09T13:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lvPsiVERyRV8FkXa_7fNoYrdYGg',
#    'id': {'kind': 'youtube#video', 'videoId': 'oHpLkdwBGEU'},
#    'snippet': {'publishedAt': '2022-04-20T15:00:12Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'India&#39;&#39;s Golden City - Jaisalmer, Rajasthan Vlog 🇮🇳',
#     'description': "In this jam-packed Rajasthan vlog, I visited India's golden city of Jaisalmer. First I went to India's only living fort, the Jaisalmer fort, ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oHpLkdwBGEU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oHpLkdwBGEU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oHpLkdwBGEU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-20T15:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TNbOvijxlpWtSFJL0ePz3_hMagE',
#    'id': {'kind': 'youtube#video', 'videoId': 'i6Fy1l98mVQ'},
#    'snippet': {'publishedAt': '2022-04-04T13:30:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Jodhpur is Intense - Rajasthan Day 1 🇮🇳',
#     'description': "Jodhpur, India's blue city, had been high on my bucket list since I watched it in one of my favorite Hollywood movies 10 years ago ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i6Fy1l98mVQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i6Fy1l98mVQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i6Fy1l98mVQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-04T13:30:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Cfwdgqhh4k28GSdUPiA4C-bc2V0',
#    'id': {'kind': 'youtube#video', 'videoId': '8kRqOHqT-yk'},
#    'snippet': {'publishedAt': '2022-03-21T07:17:58Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Sri Lanka First Impressions - Colombo Vlog 🇱🇰',
#     'description': 'Vlog from the first day in the incredible country called Sri Lanka. Join me as I explore the biggest city of the country, Colombo.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8kRqOHqT-yk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8kRqOHqT-yk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8kRqOHqT-yk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-21T07:17:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'V8t0mZxrYgaqKFN6TMjL3cM-w0Y',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLMQNNpGZnyg4ZG7V_9OKz9EFeOwnB1fRT'},
#    'snippet': {'publishedAt': '2022-03-21T05:59:33Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Sri Lanka - Nadir On The Go - English',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8kRqOHqT-yk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8kRqOHqT-yk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8kRqOHqT-yk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-21T05:59:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'E5WVSdNhPq16H_53O13rWWvr9Ns',
#    'id': {'kind': 'youtube#video', 'videoId': '6qSgNL-3hbU'},
#    'snippet': {'publishedAt': '2022-03-10T13:30:31Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': '$5 Mumbai Tour 🇮🇳',
#     'description': 'In this vlog from India, join me on a a journey through Mumbai, the financial capital of India and one of the most dynamic cities in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6qSgNL-3hbU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6qSgNL-3hbU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6qSgNL-3hbU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-10T13:30:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bE-GiWWwhh2IwkNfcPmqcRAznXY',
#    'id': {'kind': 'youtube#video', 'videoId': 'Qu5jrWdtoBw'},
#    'snippet': {'publishedAt': '2022-02-06T05:00:13Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'I Visited India&#39;s Cultural Capital - Kolkata 🇮🇳',
#     'description': 'In this vlog from Kolkata, India, I visited the spots that defined the history not just of the region but for the entire continent and the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Qu5jrWdtoBw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Qu5jrWdtoBw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Qu5jrWdtoBw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-06T05:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'u6CB9sGBsTyQOdMazuWz2SPaXDc',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLMQNNpGZnyg5y9xmIrp4FCTaCYiSl8EMy'},
#    'snippet': {'publishedAt': '2022-02-05T12:25:36Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'India- Nadir On The Go - English',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6qSgNL-3hbU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6qSgNL-3hbU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6qSgNL-3hbU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-05T12:25:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2M8fkOBFoIzET-La4rhJSWi87Po',
#    'id': {'kind': 'youtube#video', 'videoId': 'Y58RDRRNob4'},
#    'snippet': {'publishedAt': '2021-12-09T12:45:23Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Europe&#39;s Highest Settlement - Kazbegi, Georgia 🇬🇪',
#     'description': 'I headed up to North-east Georgia, only miles away from the Russian border, to go hiking in the gorgeous Caucasus mountains of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y58RDRRNob4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Y58RDRRNob4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Y58RDRRNob4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-09T12:45:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Efdib_eKnvA946gyYucflhYCD3E',
#    'id': {'kind': 'youtube#video', 'videoId': 'luzMoFIztgs'},
#    'snippet': {'publishedAt': '2021-11-25T05:30:05Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'How to Cross an International Land Border',
#     'description': "A comprehensive 15 step guide on what you should do to prepare an international land border and to be ready for what's on the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/luzMoFIztgs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/luzMoFIztgs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/luzMoFIztgs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-25T05:30:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'N9-_DUfrK0CGOZJynpQHNMC8Xjs',
#    'id': {'kind': 'youtube#video', 'videoId': 'l9HKbpJbNLg'},
#    'snippet': {'publishedAt': '2021-11-20T15:36:17Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'What I Travel the World With',
#     'description': 'A total breakdown what I travel with and basically everything I physically own, the essentials for a digital nomad and a full-time ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l9HKbpJbNLg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/l9HKbpJbNLg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/l9HKbpJbNLg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-20T15:36:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'npHpRJd1qO4d3Oj_tJoEKNAw4UY',
#    'id': {'kind': 'youtube#video', 'videoId': '5eiET04e7vw'},
#    'snippet': {'publishedAt': '2021-10-23T10:24:57Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Visiting Noah&#39;s Ark',
#     'description': 'I visited Dogubeyazit in Turkey, the historic last stop in the Ottoman empire on the way to Persia. From hilltop palaces to the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5eiET04e7vw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5eiET04e7vw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5eiET04e7vw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-23T10:24:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JSUyJmVBXdEqMbCZKB1PHiYdT8M',
#    'id': {'kind': 'youtube#video', 'videoId': 'zTZds6hdAwA'},
#    'snippet': {'publishedAt': '2021-10-20T14:45:21Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'From Empire Capital to Ghost City - Ani, Kars',
#     'description': 'This city went from one of the biggest cities in the world rivaling powerhouses like Constantinople to a deserted place in ruins on ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zTZds6hdAwA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zTZds6hdAwA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zTZds6hdAwA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-20T14:45:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-lhgM8uUPDDWdJQdnMsQ7-RFwdA',
#    'id': {'kind': 'youtube#video', 'videoId': 'peXEV8h6kjQ'},
#    'snippet': {'publishedAt': '2021-10-13T05:00:27Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Anatolian Switzerland - Trabzon, Rize',
#     'description': "This place is famous for it's green mountains covered in fogs but only looks this colorful during the summer. When I realized that ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/peXEV8h6kjQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/peXEV8h6kjQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/peXEV8h6kjQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-13T05:00:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1deEzS9MhQ2ttaHK08j_xJLzsLY',
#    'id': {'kind': 'youtube#video', 'videoId': 'w5Md_qhlr64'},
#    'snippet': {'publishedAt': '2021-10-07T05:30:05Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'I Ate Opium in Turkey..',
#     'description': 'Get Surfshark VPN at https://surfshark.deals/NADIR - enter promo code NADIR for 83% off and 3 extra months for free! I took an ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w5Md_qhlr64/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/w5Md_qhlr64/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/w5Md_qhlr64/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-07T05:30:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5dVwp6tqLusPZkRzGC44fdbrXQQ',
#    'id': {'kind': 'youtube#video', 'videoId': '9YfTy-OTd-8'},
#    'snippet': {'publishedAt': '2021-09-30T07:33:22Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Where Ancient Greece Became Turkey - Izmir',
#     'description': 'In this West Turkey vlog, I wandered through 5 cities/towns in the Izmir province on the border of the Greek Islands. I spent a week ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9YfTy-OTd-8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9YfTy-OTd-8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9YfTy-OTd-8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-30T07:33:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XPXTt305lGhozUVvI8TgGBuJvW8',
#    'id': {'kind': 'youtube#video', 'videoId': 'SIyUsbYuAto'},
#    'snippet': {'publishedAt': '2021-09-24T13:30:10Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': '$7 Middle East Road-trip',
#     'description': 'Mount Ararat is technically in Turkey but at a very interesting cross-roads between the borders of Armenia, Azerbaijan, Iran and ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SIyUsbYuAto/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SIyUsbYuAto/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SIyUsbYuAto/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-24T13:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5tB7RMB0ZPvvnzUcKjlJNJKTNpg',
#    'id': {'kind': 'youtube#video', 'videoId': '_EaQO6N04Eg'},
#    'snippet': {'publishedAt': '2021-09-13T12:50:36Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Two Lessons from Travel',
#     'description': 'Back in July 2018, I went to Belgrade for the first time. That first trip and everything else that happened during that time taught me ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_EaQO6N04Eg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_EaQO6N04Eg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_EaQO6N04Eg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-13T12:50:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zfF61iAeKTZo_hbLWyQPmAwYLY4',
#    'id': {'kind': 'youtube#video', 'videoId': 'BLBK-oBK0EY'},
#    'snippet': {'publishedAt': '2021-09-03T09:50:53Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'This is the Real Belgrade 🇷🇸',
#     'description': 'In this video, I give you a glimpse at life from my favorite city, Belgrade, take a look at Serbian culture, and a tour some of the most ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BLBK-oBK0EY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BLBK-oBK0EY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BLBK-oBK0EY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-03T09:50:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SgVqqzq43eS3vo4RrJrGNDF_MjM',
#    'id': {'kind': 'youtube#video', 'videoId': 'idlsUOvdY0U'},
#    'snippet': {'publishedAt': '2021-08-09T17:02:03Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Darkest Chapter of Balkan History - The Bosnian War 🇧🇦',
#     'description': 'In this video from Sarajevo, Bosnia, I discuss the Bosnian civil war, the most devastating conflict in Europe since the end of World ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/idlsUOvdY0U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/idlsUOvdY0U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/idlsUOvdY0U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-09T17:02:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TpcVddtgT7ruQkMOXhRSwllych0',
#    'id': {'kind': 'youtube#video', 'videoId': 'rdKNlqskags'},
#    'snippet': {'publishedAt': '2021-08-09T16:30:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'The Jerusalem of Europe - Sarajevo, Bosnia 🇧🇦',
#     'description': 'In this video, we explore one of the most fascinating cities and beautiful cities in Europe and possibly the most historic small city in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rdKNlqskags/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rdKNlqskags/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rdKNlqskags/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-09T16:30:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_zZdpJNSzVFFcHXEj9czRFaAFNk',
#    'id': {'kind': 'youtube#video', 'videoId': 'wXspMUN1CdI'},
#    'snippet': {'publishedAt': '2021-07-28T05:00:30Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Exploring Kotor - Most Underrated Mediterranean City  🇲🇪',
#     'description': 'In this Montenegro travel vlog, I explore one of the coolest coastal countries I have been too and probably one of the more ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wXspMUN1CdI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wXspMUN1CdI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wXspMUN1CdI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-28T05:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MSZOH6Wud96eoHZ5PtdH5IfQFoA',
#    'id': {'kind': 'youtube#video', 'videoId': 'BSQOVP_FU80'},
#    'snippet': {'publishedAt': '2021-07-16T11:00:11Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'First Impressions of Niš | Serbia Vlog 🇷🇸',
#     'description': "Back in Europe and excited to bring you my first ever vlog from Niš, Serbia. In this video I go through the city's attractions, ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BSQOVP_FU80/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-16T11:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'W1vLc14vqcMPrj528jkMy_23f80',
#    'id': {'kind': 'youtube#video', 'videoId': 'jV6ZRjXECpQ'},
#    'snippet': {'publishedAt': '2021-07-08T18:09:23Z',
#     'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#     'title': 'Istanbul&#39;s Story - Where Worlds Collide 🇹🇷',
#     'description': 'In this Istanbul vlog, I go through the journey of the city from Byzantium to Constantinople to finally Istanbul through the stories of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jV6ZRjXECpQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jV6ZRjXECpQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jV6ZRjXECpQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nadir On The Go',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-08T18:09:23Z'}}]}

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'ro_V3yTYa6uaNj99u4y9qbiqL-k',
#  'id': {'kind': 'youtube#video', 'videoId': 'ikdjrnVPPNY'},
#  'snippet': {'publishedAt': '2022-11-22T07:30:09Z',
#   'channelId': 'UCqlthGjbLIci7i3x2gk8P4Q',
#   'title': 'No One Could Enter OR Leave This Country for 40 years..',
#   'description': 'Sign up HERE https://bit.ly/3DKlbPG for your discounted offer to Epidemic Sound! ← The offer will be available for 5 days only.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/ikdjrnVPPNY/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Nadir On The Go',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2022-11-22T07:30:09Z'}}

# %%
video_id = response['items'][0]['id']['videoId']
video_title = response['items'][0]['snippet']['title']
video_title = video_title.replace("&amp;", "")
upload_date = response['items'][0]['snippet']['publishTime']
upload_date = upload_date.split("T")[0]

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = video_title.replace("&amp;", "")
        upload_date = video['snippet']['publishTime']
        upload_date = upload_date.split("T")[0]
        
        print(video_id)
        print(video_title)
        print(upload_date)
# Out:
# ikdjrnVPPNY
# No One Could Enter OR Leave This Country for 40 years..
# 2022-11-22
# HyiqzvOWf3k
# How did I end up on Albanian News?🇦🇱
# 2022-11-11
# NCR2elB4NWs
# Dangerous Hike in Albanian Alps 🇦🇱
# 2022-11-03
# gsN_g3UfYLc
# The Albanian Alps -  Theth to Valbona hike 🇦🇱
# 2022-10-30
# cEYcsrN6c-g
# First Day in Tirana - Albania Vlog 🇦🇱
# 2022-10-22
# CyxzEGHcLNc
# Prokletije Sunset in Montenegro 🇲🇪
# 2022-10-19
# kzi5qq7LlVw
# I Hiked from Montenegro to Albania - Peaks of the Balkans 🇲🇪
# 2022-10-06
# 39wjZlnxuWM
# Dangerous Climb Up Bobotov Kuk - Durmitor, Montenegro 🇲🇪
# 2022-09-22
# vOlxiLh8Xzg
# First Impressions of Budva, Montenegro 🇲🇪
# 2022-09-13
# GDg3l0QPEBM
# The Future of Travel - eSim Holafly Review
# 2022-08-18
# lBS04wo6E3k
# Kafanas Are Lit - Traditional Tavern in Serbia 🇷🇸
# 2022-08-17
# TlNz8nq1i-o
# In Nepal&#39;s Dangerous Jungle - Chitwan National Park 🇳🇵
# 2022-08-10
# oFcz_Vwba_I
# Fascinating Funeral Rituals in Kathmandu, Nepal 🇳🇵
# 2022-08-09
# N0KNrk2YCnU
# Journey Into the Himalayas 🇳🇵 - The Annapurna Finale
# 2022-08-02
# r8n_OqrK-Og
# Journey Into the Himalayas 🇳🇵 - Part 1 of 2
# 2022-07-29
# Jw1i5ClXi60
# Visiting Nepal&#39;s Ancient Capital City - Bhaktapur Vlog 🇳🇵
# 2022-07-21
# I6tBr9d-UmI
# Visiting Prophet Adam&#39;s First Footstep - Adam&#39;s Peak 🇱🇰
# 2022-07-13
# 89pCHrEtD6Y
# World-Famous Ella Train Ride - Sri Lanka 🇱🇰
# 2022-07-11
# ksE5SflUgiU
# Face to Face with Wild Elephant Family - Udawalawe, Sri Lanka 🇱🇰
# 2022-07-08
# awKWqzSPLa8
# Venomous Snakes  The Wildest Beaches - Sri Lanka  🇱🇰
# 2022-07-03
# zvy3ZaVIfPY
# First Impressions of Nepal - Kathmandu Day 1 🇳🇵
# 2022-06-29
# 5zDr5HhBQi0
# Agra Vlog - The Mughal Empire&#39;s Story  🇮🇳
# 2022-06-26
# dfH5c429gIk
# Attacked by Wild Monkey in Jaipur | Pink City Vlog 🇮🇳
# 2022-06-09
# f2uo7rYE3-g
# Himalayas Sunrise - Annapurna Sanctuary 🇳🇵
# 2022-05-20
# uk6PY3v3038
# Is it Safe to Travel Sri Lanka Now? 🇱🇰 - Shocking Reality of Tourist Life in the Crisis
# 2022-05-09
# oHpLkdwBGEU
# India&#39;&#39;s Golden City - Jaisalmer, Rajasthan Vlog 🇮🇳
# 2022-04-20
# i6Fy1l98mVQ
# Jodhpur is Intense - Rajasthan Day 1 🇮🇳
# 2022-04-04
# 8kRqOHqT-yk
# Sri Lanka First Impressions - Colombo Vlog 🇱🇰
# 2022-03-21
# 6qSgNL-3hbU
# $5 Mumbai Tour 🇮🇳
# 2022-03-10
# Qu5jrWdtoBw
# I Visited India&#39;s Cultural Capital - Kolkata 🇮🇳
# 2022-02-06
# Y58RDRRNob4
# Europe&#39;s Highest Settlement - Kazbegi, Georgia 🇬🇪
# 2021-12-09
# luzMoFIztgs
# How to Cross an International Land Border
# 2021-11-25
# l9HKbpJbNLg
# What I Travel the World With
# 2021-11-20
# 5eiET04e7vw
# Visiting Noah&#39;s Ark
# 2021-10-23
# zTZds6hdAwA
# From Empire Capital to Ghost City - Ani, Kars
# 2021-10-20
# peXEV8h6kjQ
# Anatolian Switzerland - Trabzon, Rize
# 2021-10-13
# w5Md_qhlr64
# I Ate Opium in Turkey..
# 2021-10-07
# 9YfTy-OTd-8
# Where Ancient Greece Became Turkey - Izmir
# 2021-09-30
# SIyUsbYuAto
# $7 Middle East Road-trip
# 2021-09-24
# _EaQO6N04Eg
# Two Lessons from Travel
# 2021-09-13
# BLBK-oBK0EY
# This is the Real Belgrade 🇷🇸
# 2021-09-03
# idlsUOvdY0U
# Darkest Chapter of Balkan History - The Bosnian War 🇧🇦
# 2021-08-09
# rdKNlqskags
# The Jerusalem of Europe - Sarajevo, Bosnia 🇧🇦
# 2021-08-09
# wXspMUN1CdI
# Exploring Kotor - Most Underrated Mediterranean City  🇲🇪
# 2021-07-28
# BSQOVP_FU80
# First Impressions of Niš | Serbia Vlog 🇷🇸
# 2021-07-16
# jV6ZRjXECpQ
# Istanbul&#39;s Story - Where Worlds Collide 🇹🇷
# 2021-07-08

# %%
url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
response_video_stats = requests.get(url_video_stats).json()

# %%
response_video_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'gY3K3kYEQlu434Jnv0BBvKrJS68',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'RDJEeWOL_IPeuIQfaV5EEsrt1FI',
#    'id': 'jV6ZRjXECpQ',
#    'statistics': {'viewCount': '35359',
#     'likeCount': '3644',
#     'favoriteCount': '0',
#     'commentCount': '334'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
if 'viewCount' in response_video_stats['items'][0]['statistics']:
    view_count = response_video_stats['items'][0]['statistics']['viewCount']
else:
    view_count = None
if 'likeCount' in response_video_stats['items'][0]['statistics']:
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
else:
    like_count = None
if 'dislikeCount' in response_video_stats['items'][0]['statistics']:
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
else:
    dislike_count = None
if 'commentCount' in response_video_stats['items'][0]['statistics']:
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']
else:
    comment_count = None

# %%
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count", "dislike_count", "comment_count"])

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = video_title.replace("&amp;", "")
        upload_date = video['snippet']['publishTime']
        upload_date = upload_date.split("T")[0]
        
        url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
        response_video_stats = requests.get(url_video_stats).json()
        if 'viewCount' in response_video_stats['items'][0]['statistics']:
            view_count = response_video_stats['items'][0]['statistics']['viewCount']
        else:
            view_count = None
        if 'likeCount' in response_video_stats['items'][0]['statistics']:
            like_count = response_video_stats['items'][0]['statistics']['likeCount']
        else:
            like_count = None
        if 'dislikeCount' in response_video_stats['items'][0]['statistics']:
            dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
        else:
            dislike_count = None
        if 'commentCount' in response_video_stats['items'][0]['statistics']:
            comment_count = response_video_stats['items'][0]['statistics']['commentCount']
        else:
            comment_count = None
        """
        print(video_id)
        print(video_title)
        print(upload_date)
        print(view_count)
        print(like_count)
        print(dislike_count)
        print(comment_count)
        """
        #save data in pandas dataframe
        df = df.append({'video_id':video_id, 'video_title':video_title,
                        'upload_date':upload_date, 'view_count':view_count,
                        'like_count':like_count, 'dislike_count':dislike_count,
                        'comment_count':comment_count}, ignore_index=True)
# Out:
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/489005760.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,

# %%
df.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  ikdjrnVPPNY  No One Could Enter OR Leave This Country for 4...  2022-11-22
# 1  HyiqzvOWf3k               How did I end up on Albanian News?🇦🇱  2022-11-11
# 2  NCR2elB4NWs                 Dangerous Hike in Albanian Alps 🇦🇱  2022-11-03
# 3  gsN_g3UfYLc      The Albanian Alps -  Theth to Valbona hike 🇦🇱  2022-10-30
# 4  cEYcsrN6c-g              First Day in Tirana - Albania Vlog 🇦🇱  2022-10-22
#
#   view_count like_count dislike_count comment_count
# 0        809        151          None            18
# 1      41071       2566          None           143
# 2       8702        833          None            21
# 3      45541       2932          None           212
# 4     125961       5939          None           486

# %%
def call_api(api_key, channel_id):
    pageToken = ""
    url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+'&channelId='+channel_id+'&part=snippet,id&order=date&maxResults=10000'+pageToken
    response = requests.get(url).json()
    return response

# %%
def get_video_details(video_id):
    url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
    response_video_stats = requests.get(url_video_stats).json()
    if 'viewCount' in response_video_stats['items'][0]['statistics']:
        view_count = response_video_stats['items'][0]['statistics']['viewCount']
    else:
        view_count = None
    if 'likeCount' in response_video_stats['items'][0]['statistics']:
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
    else:
        like_count = None
    if 'dislikeCount' in response_video_stats['items'][0]['statistics']:
        dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
    else:
        dislike_count = None
    if 'commentCount' in response_video_stats['items'][0]['statistics']:
        comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    else:
        comment_count = None
    
    return view_count, like_count, dislike_count, comment_count

# %%
def get_videos(response, df):
    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            video_title = video_title.replace("&amp;", "")
            upload_date = video['snippet']['publishTime']
            upload_date = upload_date.split("T")[0]
            
            view_count, like_count, dislike_count, comment_count = get_video_details(video_id)

            #save data in pandas dataframe
            df = df.append({'video_id':video_id, 'video_title':video_title,
                            'upload_date':upload_date, 'view_count':view_count,
                            'like_count':like_count, 'dislike_count':dislike_count,
                            'comment_count':comment_count}, ignore_index=True)
    return df

# %%
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count", "dislike_count", "comment_count"])

# %%
# keys
api_key = 'AIzaSyASeS22KBi2mR8qjf8PRJvGWkzwU9py5pQ'
channel_id = 'UCqlthGjbLIci7i3x2gk8P4Q'
response = call_api(api_key, channel_id)
df = get_videos(response, df)
# Out:
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# /tmp/ipykernel_11707/4149849765.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,

# %%
df.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  ikdjrnVPPNY  No One Could Enter OR Leave This Country for 4...  2022-11-22
# 1  HyiqzvOWf3k               How did I end up on Albanian News?🇦🇱  2022-11-11
# 2  NCR2elB4NWs                 Dangerous Hike in Albanian Alps 🇦🇱  2022-11-03
# 3  gsN_g3UfYLc      The Albanian Alps -  Theth to Valbona hike 🇦🇱  2022-10-30
# 4  cEYcsrN6c-g              First Day in Tirana - Albania Vlog 🇦🇱  2022-10-22
#
#   view_count like_count dislike_count comment_count
# 0        824        154          None            20
# 1      41072       2566          None           143
# 2       8702        833          None            21
# 3      45541       2932          None           212
# 4     125961       5939          None           486
