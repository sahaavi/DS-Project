# %%
# import libraries
import requests
import pandas as pd
import time 
#from googleapiclient.discovery import build

# %%
# keys
api_key = 'AIzaSyASeS22KBi2mR8qjf8PRJvGWkzwU9py5pQ'
channel_id = 'UCCqMCs7QzheL7o-gtCwsmvw'

# %% [markdown]
# api_service_name = "youtube"
# api_version = "v3"
# youtube = build(api_service_name, api_version, developerKey = api_key)

# %%
# make api call
pageToken = ""
url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+'&channelId='+channel_id+'&part=snippet,id&order=date&maxResults=10000'+pageToken
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'M784lh4olnPGHwaQzdu6Slh7KG0',
#  'regionCode': 'CA',
#  'pageInfo': {'totalResults': 18, 'resultsPerPage': 18},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'nmWjeApebt32NFwkPm045wOENf0',
#    'id': {'kind': 'youtube#video', 'videoId': 'PuYcznNhf3Q'},
#    'snippet': {'publishedAt': '2022-11-02T05:30:03Z',
#     'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#     'title': 'Make Me Believe (Official Video) Shankuraj Konwar &amp; EREKA | Hyundai Spotlight',
#     'description': 'Get ready to go on a journey of rediscovering yourself with the magical voices of Shankuraj Konwar and EREKA in the English ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PuYcznNhf3Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PuYcznNhf3Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PuYcznNhf3Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hyundai Spotlight',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-02T05:30:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_GgTOBRFsDQ8MsdMqK5LQkcQrgc',
#    'id': {'kind': 'youtube#video', 'videoId': '3qwe5mxCLg4'},
#    'snippet': {'publishedAt': '2022-11-01T05:30:03Z',
#     'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#     'title': 'Make Me Believe (Official Teaser) Shankuraj Konwar &amp; EREKA | Hyundai Spotlight',
#     'description': 'When life gives you wheels, drive into the depths of the earth and find yourself! Lose yourself in the euphonious voices of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3qwe5mxCLg4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3qwe5mxCLg4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3qwe5mxCLg4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hyundai Spotlight',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-01T05:30:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'u3oWtBcA2RQP365H8jVZZ41lmPQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZHizdar6FQA'},
#    'snippet': {'publishedAt': '2022-10-14T05:30:11Z',
#     'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#     'title': 'Pyaar Mein (Acoustic Version) Nikhita Gandhi &amp; Denny | Hyundai Spotlight',
#     'description': "Nikhita and Denny's jodi just got even more romantic with this intimate acoustic rendition of their single 'Pyaar Mein'.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZHizdar6FQA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZHizdar6FQA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZHizdar6FQA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hyundai Spotlight',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-14T05:30:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rRr_H5Jk1WqhYrdNnlMKZY4YKiE',
#    'id': {'kind': 'youtube#video', 'videoId': 'OIo1T5TdBEM'},
#    'snippet': {'publishedAt': '2022-10-11T05:30:05Z',
#     'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#     'title': 'Pyaar Mein (Behind The Scenes) Nikhita Gandhi &amp; Denny | Hyundai Spotlight',
#     'description': 'Eyes met, hearts sang, love blossomed and memories made... But how? Watch the love story of Nikhita and Denny come to life in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OIo1T5TdBEM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OIo1T5TdBEM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OIo1T5TdBEM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hyundai Spotlight',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-11T05:30:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i3ZVCJTLY3A5LIfK4XgqkC08dlE',
#    'id': {'kind': 'youtube#video', 'videoId': 'u2kG4tX9qHc'},
#    'snippet': {'publishedAt': '2022-09-23T05:29:59Z',
#     'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#     'title': '
z',
#     'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#     'title': 'Dhoondein Sitaare (Behind The Scenes) Aastha Gill &amp; King | Hyundai Spotlight',
#     'description': "Catch the exclusive Behind The Scenes of 'Dhoondein Sitaare' as our sitaare Aastha Gill & King have absolute fun while making ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6Q3urJPgn2Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6Q3urJPgn2Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6Q3urJPgn2Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hyundai Spotlight',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-02T05:29:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZFbbJrd8rI2WmBS2BKHJAXLViOI',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw'},
#    'snippet': {'publishedAt': '2021-11-09T08:11:11Z',
#     'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#     'title': 'Hyundai Spotlight',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/JjhrwwM9gBru4vDGchjSgEmyldpGdpdirbBVy8f1ha0W0kjj3Fc0bS-h1RO1HuHcNVDfTwWB2S4=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/JjhrwwM9gBru4vDGchjSgEmyldpGdpdirbBVy8f1ha0W0kjj3Fc0bS-h1RO1HuHcNVDfTwWB2S4=s240-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/JjhrwwM9gBru4vDGchjSgEmyldpGdpdirbBVy8f1ha0W0kjj3Fc0bS-h1RO1HuHcNVDfTwWB2S4=s800-c-k-c0xffffffff-no-rj-mo'}},
#     'channelTitle': 'Hyundai Spotlight',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-09T08:11:11Z'}}]}

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'nmWjeApebt32NFwkPm045wOENf0',
#  'id': {'kind': 'youtube#video', 'videoId': 'PuYcznNhf3Q'},
#  'snippet': {'publishedAt': '2022-11-02T05:30:03Z',
#   'channelId': 'UCCqMCs7QzheL7o-gtCwsmvw',
#   'title': 'Make Me Believe (Official Video) Shankuraj Konwar &amp; EREKA | Hyundai Spotlight',
#   'description': 'Get ready to go on a journey of rediscovering yourself with the magical voices of Shankuraj Konwar and EREKA in the English ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PuYcznNhf3Q/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/PuYcznNhf3Q/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/PuYcznNhf3Q/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Hyundai Spotlight',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2022-11-02T05:30:03Z'}}

# %%
video_id = response['items'][0]['id']['videoId']
video_title = response['items'][0]['snippet']['title']
video_title = video_title.replace("&amp;", "")
upload_date = response['items'][0]['snippet']['publishTime']
upload_date = upload_date.split("T")[0]

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = video_title.replace("&amp;", "")
        upload_date = video['snippet']['publishTime']
        upload_date = upload_date.split("T")[0]
        
        print(video_id)
        print(video_title)
        print(upload_date)
# Out:
# PuYcznNhf3Q
# Make Me Believe (Official Video) Shankuraj Konwar  EREKA | Hyundai Spotlight
# 2022-11-02
# 3qwe5mxCLg4
# Make Me Believe (Official Teaser) Shankuraj Konwar  EREKA | Hyundai Spotlight
# 2022-11-01
# ZHizdar6FQA
# Pyaar Mein (Acoustic Version) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-10-14
# OIo1T5TdBEM
# Pyaar Mein (Behind The Scenes) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-10-11
# u2kG4tX9qHc
# Pyaar Mein (Official Video) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-09-23
# lwfa4yJwP_k
# Pyaar Mein (Official Teaser) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-09-22
# w1FQ_crkQVg
# Oorukaaran (Acoustic Version)  ERA | Hyundai Spotlight
# 2022-08-04
# 7RBgtOZ_w1E
# Hiphop Tamizha - Oorukaaran (Behind the Scenes) ERA | Hyundai Spotlight
# 2022-07-19
# McuNeFqeVHA
# Hiphop Tamizha - Oorukaaran (Official Video) ERA | Hyundai Spotlight
# 2022-06-09
# 3Vbh_2OGeHI
# Easy Na Lai (Acoustic) - Official Video | Shehnaz Akhtar | Hyundai Spotlight
# 2022-05-24
# wAnLg8vDwXE
# Easy Na Lai (Acoustic Version) Rahul Jain | Asees Kaur | Sahil  Shehnaz Akhtar | Gag Studioz
# 2022-05-17
# bdhyZ2UX83g
# Easy Na Lai (Behind The Scenes) Asees Kaur | Sahil  Shehnaz Akhtar | Gag Studioz
# 2022-04-26
# YrBrM8G-AGo
# Asees Kaur - Easy Na Lai | #shorts
# 2022-04-10
# W_U-OC5CCaI
# Easy Na Lai (Official Video) Asees Kaur | Sahil  Shehnaz Akhtar | Gag Studioz | Hyundai Spotlight
# 2022-04-07
# EyDOH36YWBU
# Dhoondein Sitaare - Acoustic (Official Video) Aastha Gill  King | Hyundai Spotlight
# 2022-03-03
# XcK1AhJ4D34
# Dhoondein Sitaare (Official Video) Aastha Gill  King | Hyundai Spotlight
# 2021-12-03
# 6Q3urJPgn2Y
# Dhoondein Sitaare (Behind The Scenes) Aastha Gill  King | Hyundai Spotlight
# 2021-12-02

# %%
url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
response_video_stats = requests.get(url_video_stats).json()

# %%
response_video_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'sQ7XC4NyV_KNrk5tk4jOAkJXZiE',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'YGMKAeoKHPHx2iyGI8rsIUy9RMs',
#    'id': '6Q3urJPgn2Y',
#    'statistics': {'viewCount': '26773',
#     'likeCount': '1412',
#     'favoriteCount': '0',
#     'commentCount': '61'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
view_count = response_video_stats['items'][0]['statistics']['viewCount']
like_count = response_video_stats['items'][0]['statistics']['likeCount']
#dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
comment_count = response_video_stats['items'][0]['statistics']['commentCount']

# %%
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count", "dislike_count", "comment_count"])

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        video_title = video_title.replace("&amp;", "")
        upload_date = video['snippet']['publishTime']
        upload_date = upload_date.split("T")[0]
        
        url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+api_key
        response_video_stats = requests.get(url_video_stats).json()
        
        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        #dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
        comment_count = response_video_stats['items'][0]['statistics']['commentCount']
        """
        print(video_id)
        print(video_title)
        print(upload_date)
        print(view_count)
        print(like_count)
        #print(dislike_count)
        print(comment_count)
        """
        #save data in pandas dataframe
        df = df.append
# Out:
# PuYcznNhf3Q
# Make Me Believe (Official Video) Shankuraj Konwar  EREKA | Hyundai Spotlight
# 2022-11-02
# 4081553
# 13168
# 223
# 3qwe5mxCLg4
# Make Me Believe (Official Teaser) Shankuraj Konwar  EREKA | Hyundai Spotlight
# 2022-11-01
# 4549
# 46
# 0
# ZHizdar6FQA
# Pyaar Mein (Acoustic Version) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-10-14
# 129030
# 793
# 10
# OIo1T5TdBEM
# Pyaar Mein (Behind The Scenes) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-10-11
# 2671
# 28
# 1
# u2kG4tX9qHc
# Pyaar Mein (Official Video) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-09-23
# 10803150
# 54211
# 329
# lwfa4yJwP_k
# Pyaar Mein (Official Teaser) Nikhita Gandhi  Denny | Hyundai Spotlight
# 2022-09-22
# 2244
# 43
# 3
# w1FQ_crkQVg
# Oorukaaran (Acoustic Version)  ERA | Hyundai Spotlight
# 2022-08-04
# 9390
# 518
# 46
# 7RBgtOZ_w1E
# Hiphop Tamizha - Oorukaaran (Behind the Scenes) ERA | Hyundai Spotlight
# 2022-07-19
# 7835
# 495
# 21
# McuNeFqeVHA
# Hiphop Tamizha - Oorukaaran (Official Video) ERA | Hyundai Spotlight
# 2022-06-09
# 11378966
# 162173
# 2244
# 3Vbh_2OGeHI
# Easy Na Lai (Acoustic) - Official Video | Shehnaz Akhtar | Hyundai Spotlight
# 2022-05-24
# 123044
# 576
# 20
# wAnLg8vDwXE
# Easy Na Lai (Acoustic Version) Rahul Jain | Asees Kaur | Sahil  Shehnaz Akhtar | Gag Studioz
# 2022-05-17
# 55447
# 337
# 40
# bdhyZ2UX83g
# Easy Na Lai (Behind The Scenes) Asees Kaur | Sahil  Shehnaz Akhtar | Gag Studioz
# 2022-04-26
# 33896
# 61
# 2
# YrBrM8G-AGo
# Asees Kaur - Easy Na Lai | #shorts
# 2022-04-10
# 11270
# 938
# 7
# W_U-OC5CCaI
# Easy Na Lai (Official Video) Asees Kaur | Sahil  Shehnaz Akhtar | Gag Studioz | Hyundai Spotlight
# 2022-04-07
# 10116997
# 76661
# 5284
# EyDOH36YWBU
# Dhoondein Sitaare - Acoustic (Official Video) Aastha Gill  King | Hyundai Spotlight
# 2022-03-03
# 421589
# 33490
# 700
# XcK1AhJ4D34
# Dhoondein Sitaare (Official Video) Aastha Gill  King | Hyundai Spotlight
# 2021-12-03
# 17331258
# 191129
# 2293
# 6Q3urJPgn2Y
# Dhoondein Sitaare (Behind The Scenes) Aastha Gill  King | Hyundai Spotlight
# 2021-12-02
# 26773
# 1412
# 61

# %%
dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
